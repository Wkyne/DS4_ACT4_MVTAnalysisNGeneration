# %% [markdown]
# <a href="https://colab.research.google.com/github/Wkyne/DS4_ACT4_MVTAnalysisNGeneration/blob/main/DS4_ACT4_MVTAnalysisNGeneration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Multi-Variant Text Analysis and Generation
#
# > **Course Activity** | BERT, GPT, and GANs
# > **Dataset:** | Placeholder
#
# ---
# Submitted by:
# Granada, Dustin Joaquin B.
# Dequinon, Rob Eugene
# Gallor, Michael Edward II
#
# ---
# Group 1 CSS182-04 CM2

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.schedules import CosineDecay
import matplotlib.pyplot as plt
import numpy as np
import os

import os  # This imports the os module for working with folders and file paths. It is necessary for navigating dataset directories.
import shutil  # This imports shutil for copying files from one folder to another. It is used to move only valid images into a clean dataset folder.
from PIL import Image  # This imports the Python Imaging Library for opening and verifying image files. It helps detect corrupted or unreadable images before training.
import kagglehub  # This imports KaggleHub which is used to directly download datasets from Kaggle into the notebook. It simplifies dataset access without manual uploads.

# %%
path = kagglehub.dataset_download("stealthtechnologies/traffic-time-series-dataset")  # This downloads the Cats vs Dogs dataset from Kaggle and stores the returned path. It ensures the dataset is available for preprocessing and training.
print("Downloaded to:", path)  # This prints the exact location where the dataset was downloaded. It helps confirm the correct directory for later use.

# %%
3. Dataset Description
3.1 Dataset Source
3.2 Sequence Characteristics
3.3 Data Cleaning
3.4 Tokenization
4. Environment Setup
4.1 Library Installation
4.2 Import Libraries
PART 1 – DATA PREPARATION
5. Data Loading
5.1 Dataset Import
5.2 Preprocessing Pipeline
5.3 Sequence Padding
5.4 Train/Test Split
PART 2 – REFERENCE MODEL
6. Sample Architecture Review
6.1 Download Sample Model
6.2 Architecture Discussion
6.3 Key Components
PART 3 – MODEL BUILDING
7. Model A – RNN + LSTM
7.1 Architecture Design
7.2 Model Summary
7.3 Training Process
8. Model B – RNN + GRU
8.1 Architecture Design
8.2 Model Summary
8.3 Training Process
PART 4 – EVALUATION
9. Evaluation Metrics
9.1 Accuracy or MSE
9.2 mAP
9.3 Training Time
10. Results Comparison
10.1 Performance Table
10.2 Accuracy/MSE Plot
10.3 Loss Plot
PART 5 – DISCUSSION
11. Convergence Analysis
11.1 Which Model Converged Faster?
11.2 LSTM vs GRU Performance
11.3 Computational Efficiency
12. Hidden State Analysis
12.1 Context Retention
12.2 Long-Term Dependencies
12.3 Comparison with Non-Recurrent Networks
13. Conclusion
14. Colab Link
